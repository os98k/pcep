# %%
print("Pakistan Zindabad")
print(2,3)
print("SMIT", "Saylani")
print()
print("Python")
# Out:
# Pakistan Zindabad
# 2 3
# SMIT Saylani
#
# Python

# %% [markdown]
# Print:
# print is a python function(action) that print the value given, on the console.
#
# The value given to print(function) called "argument".

# %%
print("argument1",        "argument2", "argument3", 4, 6)
# Out:
# argument1 argument2 argument3 4 6

# %% [markdown]
# Possible arguments in a print function:
#  numbers, alphabets

# %%
print(1,2,3,4,5,6 ,sep="<>")   # end , sep
# Out:
# 1<>2<>3<>4<>5<>6

# %%
print("Nasir", "Hussain", sep="*****")
# Out:
# Nasir*****Hussain

# %%
print("Pakistan",end="")  # escape character \n >>> newline
print("USA" ,end="")
print("China",end="\n")
print("Afghnistan")
# Out:
# PakistanUSAChina
# Afghnistan

# %%
print("we are all \n learners of \nPython")
# Out:
# we are all
#  learners of
# Python

# %%
print("Pakistan",end="\t")  # escape character \t >>> tab
print("USA" ,end="\t")
print("China",end="\t")
print("Afghnistan")
# Out:
# Pakistan	USA	China	Afghnistan

# %% [markdown]
# **Escape Characters**:
# How many escape character are in python???

# %% [markdown]
# **Signature:**
# ctr+spacebar

# %%
print("we are all \tlearners of \tPython")
# Out:
# we are all 	learners of 	Python

# %% [markdown]
# **Type of values:(Data)**
# Integers, floats, booleans, strings

# %%
print("This is a string")  # string
print(100)                 # integer
print(20.56789)            #flaot
print(True)                # bool
print(False)               # bool
# Out:
# This is a string
# 100
# 20.56789
# True
# False

# %%
print("This is a string", 100, 20.3456, True, False)
    #     string           int    float  bool  bool
# Out:
# This is a string 100 20.3456 True False

# %%
print('this is a string')
# Out:
# this is a string

# %%
# This is my friend's book
print("This is my friend's book")
# Out:
# This is my friend's book

# %%
# this is "Python" programming language class.

print("this is \"Python\" programming language class")
# Out:
# this is "Python" programming language class

# %%
# Vary>>> changable >increse>>decrease 

# Real world quantities: Age , Height, Weight, Date, days
#                         bloodgroup,

# %%
# Variable: container

# %%
# creating a variable  assigning a variable
age  =   "Hello"
# variable name is age
# variable value is 50 
# variable value type integer (int)
# this code is read as >> int 50 is assigned to a variable who name(identifier)
# is age

# "=" is an operator is called assignment operator

# %%
type(age)
# Out:
# str

# %%
# integer variable
marks = 900

# float variable
percentage = 90.6

# String variable
college = "SMIT"

# boolean variable
examPasses= True
feesPaid= False

# %%
print(type(marks),type(percentage),type(college),type(examPasses),type(feesPaid))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'> <class 'bool'>

# %%
print(marks) # it is not string it is a name of variable
             # the name of variable will not be in quaotation

print("marks")
# Out:
# 10
# marks

# %%
#checking memory address of variable
id(marks)
# Out:
# 140682321474864

# %%
marks = 10

# %%
marks
# Out:
# 10

# %%
# String data type

'String'
"This is also string"
# Out:
# 'This is also string'

# %%
#escape character

print("my name is \nnasir")
print("Hello \tPython")
# Out:
# my name is
# nasir
# Hello 	Python
